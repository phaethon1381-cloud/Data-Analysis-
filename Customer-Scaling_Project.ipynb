# %% [markdown]
# # Customer Dataset Analysis (EDA)
#
# Correlation Analysis + Scaling Comparison

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['figure.figsize'] = (8,5)

# %% [markdown]
# ## Load Dataset

# %%
# Replace with your dataset path
df = pd.read_csv('Mall_Customers.csv')

df.head()

# %% [markdown]
# ## Basic Information

# %%
print(df.info())
print("\nMissing Values:\n")
print(df.isnull().sum())

df.describe()

# %% [markdown]
# ## Correlation Analysis

# %%
numeric_df = df.select_dtypes(include='number')

corr = numeric_df.corr()

plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## Income vs Spending Score

# %%
sns.scatterplot(
    data=df,
    x='Annual Income (k$)',
    y='Spending Score (1-100)'
)

plt.title('Income vs Spending Score')
plt.show()

# %% [markdown]
# ## Gender vs Spending Score

# %%
sns.boxplot(
    data=df,
    x='Gender',
    y='Spending Score (1-100)'
)

plt.title('Gender vs Spending Score')
plt.show()

# %% [markdown]
# ## Encode Gender

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['Gender_Encoded'] = le.fit_transform(df['Gender'])

df[['Gender','Gender_Encoded']].head()

# %% [markdown]
# ## Unscaled Features

# %%
X = df[['Age',
        'Annual Income (k$)',
        'Spending Score (1-100)']]

X.head()

# %% [markdown]
# ## Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

scaled_df = pd.DataFrame(
    X_scaled,
    columns=X.columns
)

scaled_df.head()

# %% [markdown]
# ## Compare Before and After Scaling

# %%
fig, ax = plt.subplots(1,2, figsize=(12,5))

ax[0].boxplot(X)
ax[0].set_title('Before Scaling')

ax[1].boxplot(X_scaled)
ax[1].set_title('After Scaling')

plt.show()

# %% [markdown]
# ## Conclusions
#
# - Check whether income affects spending score.
# - Check whether age affects spending score.
# - Compare gender groups.
# - Observe how scaling standardizes feature ranges.
# - Use findings in your final report.
